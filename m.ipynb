# %%
from matplotlib import pyplot as plt 
import numpy as np 
import pandas as pd

# %%
#data
a=np.arange(1,11)
b=np.random.uniform(11,15,10)

#seting the plot
fig=plt.figure(figsize=(4,4))

#feeding data
plt.plot(a,b)

#Labeling
plt.xlim(0,12)
plt.ylim(11,16)
plt.xlabel("X AXIS")
plt.ylabel('Y AXIS')
plt.title("FIG 1",size=10)
plt.suptitle("graph 1",size=15)
# Out:
# Text(0.5, 0.98, 'graph 1')

# %%
# points 

a=np.arange(1,11)
b=np.random.uniform(11,15,10)

#seting the plot
fig=plt.figure(figsize=(5,5))

#feeding data
plt.plot(a,b,"r-*")

#Labeling
plt.xlim(0,12)
plt.ylim(11,16)
plt.xlabel("X AXIS")
plt.ylabel('Y AXIS')
plt.title("FIG 1",size=10)
plt.suptitle("graph 1",size=15)

for i,j in zip(a,b):
    plt.text(i,j,"({},{:.1f})".format(i,j))

# %%
# subplots 1
plt.subplots(4)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object))

# %%
#subplots 2
plt.subplots(1,2)
# Out:
# (<Figure size 640x480 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
fig,s=plt.subplots(3,3)

# %%
a=np.arange(1,11)
b=np.random.uniform(11,15,10)
s[0,2].plot(a,b)

# %%
fig,s=plt.subplots(3,3)
a=np.arange(1,11)
b=np.random.uniform(11,15,10)
s[0,0].plot(a,b,'tab:red')
s[0,1].plot(a,b,'tab:green')
s[0,2].plot(a,b,'tab:orange')
s[1,0].plot(a,b,'tab:grey')
s[1,1].plot(a,b,'tab:purple')
s[1,2].plot(a,b,'tab:pink')
s[2,0].plot(a,b,'tab:green')
s[2,1].plot(a,b,'tab:blue')
s[2,2].plot(a,b,'tab:brown')
